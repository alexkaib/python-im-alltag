# %% [markdown]
# # Teil XY: Webscraping
# Mit `requests` können wir bereits auf Internetressourcen zugreifen, darunter APIs mit strukturierten Daten. Der Großteil des Internets besteht allerdings aus Webseiten, die für Menschen und nicht Maschinen gemacht sind. Um sie in Python zu verarbeiten, benötigen wir neue Tools und ein Grundverständnis der zugrundeliegenden Technologie.

# %% [markdown]
# ## X.0 Die Auszeichnungssprache HTML

# %% [markdown]
# Webseiten bestehen nicht nur aus Text - praktisch jede Seite besitzt Überschriften, Bilder, Links und viele andere **Strukturelemente**. Die [Hypertext Markup Language (HTML)](https://de.wikipedia.org/wiki/Hypertext_Markup_Language) ist die Standardsprache, um diese Elemente zu definieren. Dafür werden **Tags** genutzt, die entweder für sich stehen oder als eine Art Klammer vor und nach einen Text stehen.
#
# Nebenbemerkung: Die **visuelle Darstellung** einer Webseite wird getrennt davon mit [Cascading Style Sheets (CSS)](https://de.wikipedia.org/wiki/Cascading_Style_Sheets) festgelegt, die uns glücklicherweise hier nicht interessieren.

# %% [markdown]
# ### Überschriften, Blöcke, Absätze, Links und Bilder

# %% [markdown]
# Die wichtigsten HTML-Elemente für unsere Zwecke sind:
# - Überschriften, markiert durch das Tag-Paar `<h1>` und `</h1>` bzw. `<h2>`, `<h3>`, `<h4>`, `<h5>` und `<h6>`.
# - Blöcke, markiert durch das Tag-Paar `<div>` und `</div>`.
# - Absätze, markiert durch das Tag-Paar `<p>` und `</p>`.
# - Links, markiert durch das Tag-Paar `<a>` und `</a>`.
# - Bilder, markiert durch den alleinstehenden Tag `<img>`.
#
# Am Rande sei außerdem auf `<ul>`, `<ol>` und `<li>` für Listen verwiesen (s. https://www.w3schools.com/html/html_lists.asp).

# %% [markdown]
# ### 🧪Experiment: HTML verändern

# %% [markdown]
# Der folgende HTML-Code definiert eine einfache Webseite, die darunter abgebildet ist.
#
# ```html
# <h3>Meine Webseite</h3>
# <img src="https://cdn.pixabay.com/photo/2016/05/08/14/58/icon-1379228_1280.png" width="200em">
# <div>
#     <p>Lorem ipsum dolor sit amet, consetetur sadipscing elitr, sed diam nonumy eirmod tempor invidunt ut labore et dolore magna aliquyam erat, sed diam voluptua.</p>
#     <p>At vero eos et accusam et justo duo dolores et ea rebum. Stet clita kasd gubergren, no sea takimata sanctus est Lorem ipsum dolor sit amet.</p>
# </div>
# <h4>Was heißt das?</h4>
# <div>
#     <p>Vielleicht fragst du dich, was die einleitenden Absätze bedeuten. Die Antwort ist: Nichts! Es handelt sich um <a href="https://de.wikipedia.org/wiki/Lorem_ipsum">Lorem Ipsum</a>, einen klassischen Platzhaltertext.</p>
# </div>
# ```

# %% [markdown]
# Mit einem **Doppel-Klick auf das untenstehende Textfeld** kannst du den zugrundeliegenden HTML-Code einsehen und bearbeiten. Ändere ihn ein wenig ab und sie dir das Ergebnis an. Versuche, die **Reihenfolge der Überschriften** zu ändern, **Tags** zu entfernen und einen **neuen Link** zu einer anderen Webseite einzufügen.

# %% [markdown]
# <h1>Meine Webseite</h1>
# <img src="https://cdn.pixabay.com/photo/2016/05/08/14/58/icon-1379228_1280.png" width="200em">
# <div>
#     <p>Lorem ipsum dolor sit amet, consetetur sadipscing elitr, sed diam nonumy eirmod tempor invidunt ut labore et dolore magna aliquyam erat, sed diam voluptua.</p>
#     <p>At vero eos et accusam et justo duo dolores et ea rebum. Stet clita kasd gubergren, no sea takimata sanctus est Lorem ipsum dolor sit amet.</p>
# </div>
# <h2>Was heißt das?</h2>
# <div>
#     <p>Vielleicht fragst du dich, was die einleitenden Absätze bedeuten. Die Antwort ist: Nichts! Es handelt sich um <a href="https://de.wikipedia.org/wiki/Lorem_ipsum">Lorem Ipsum</a>, einen klassischen Platzhaltertext.</p>
# </div>

# %% [markdown]
# ### Attribute

# %% [markdown]
# Im vorherigen Beispiel sind bereits zwei **Attribute** aufgetaucht:
# - `href`, um die Adresse eines Links zu definieren
# - `src`, um den Speicherort einer Bilddatei zu benennen.
#
# Ein Attribut steht innerhalb eines Tags direkt nach dem Elementnamen, getrennt durch ein Leerzeichen. Wie **Schlüsselwortparameter** in Python besteht das Attribut aus dem Namen des Attributs, einem `=` und dem Wert des Attributs:
# ```html
# <ELEMENT ATTRIBUT=WERT>...</ELEMENT>
# ```
#
# Ein Element kann auch mehrere Attribute besitzen, die mit Leerzeichen getrennt werden:
# ```html
# <ELEMENT ATTRIBUT1=X ATTRIBUT2=Y ATTRIBUT3=Z>...</ELEMENT>
# ```
#
# Für unsere Zwecke sind zwei Attribute besonders wichtig: `class` und `id`. Eine Klasse ist meist mehreren Elementen zugeordnet, um die Elemente als zusammengehörig zu markieren. IDs  zeichnen hingegen ein bestimmtes Element aus.

# %% [markdown]
# ### 🧪Experiment: HTML-Klassen
# Füge dem untenstehenden `<div>`-Tag das `class`-Attribut hinzu und setze seinen Wert auf einen beliebigen String. Setze ihn anschließend auf "jp-Collapse-header". Hast du eine Vermutung, was passiert?

# %% [markdown]
# <div>
#     Doppel-Klick hier!
# </div>

# %% [markdown]
# ### Zusammenfassung

# %% [markdown]
# Für Webscraping mit Pyhton sollten wir folgende Dinge über HTML wissen:
# - Eine Webseite besteht aus **Elementen** wie Überschriften, Blöcken und Links.
# - Diese Elemente werden mit **Tags** gekennzeichnet, z.B. `<p>...</p>`.
# - Elemente können **Attribute** enthalten, z.B. `href` für Linkadressen.
# - Elemente können **Klassen** und **IDs** besitzen, mit denen sie maschinell identifiziert werden können.

# %% [markdown]
# ## 1. Webseiten finden

# %% [markdown]
# Im Verlauf dieses Kapitels werden wir einen Crawler entwickeln, der die Webseiten des LehrLernZentrums verarbeitet, um **alle Seminare für Studierende chronologisch aufzulisten**.
#
# Der erste Schritt besteht darin, die Webseite mit Hinblick auf unser Ziel zu analysieren: https://www.hs-rm.de/lehrlernzentrum

# %% [markdown]
# ### 🛠️Übung: Relevante Seiten finden
# Durchsuche die Webseiten des LLZ. Welche Unterseite(n) sind vielversprechend, um die benötigten Informationen zu erhalten?

# %% [raw]
# # Platz für URLs

# %% [markdown]
# ## 2. Webseiten untersuchen

# %% [markdown]
# Die meisten Webbrowser (Chrome, Firefox, etc.) stellen **Entwicklertools** zur Verfügung, mit denen wir den HTML-Code einer Seite analysieren können. Meist reicht ein **Rechtsklick** und dann die Option **Untersuchen** bzw. **Inspect**. Es sollte sich dann eine Seitenleiste öffnen, bei der ggf. noch der Tab **Elemente** oder **Inspektor** ausgewählt werden muss.
#
# In dieser Ansicht können wir uns den HTML-Code neben der gerenderten Webseite anschauen und so die Elemente identifizieren, die uns interessieren. Dabei ist es nützlich, besonders auf **Klassen**, **IDs** und **Element-Verschachtelungen** zu achten: Diese werden es uns später erlauben, gezielt auf bestimmte Informationen zuzugreifen.
#
# Wir schauen uns das zusammen an der LLZ-Webseite an: https://www.hs-rm.de/lehrlernzentrum

# %% [markdown]
# ### 🛠️Übung: Elemente identifizieren
# Nutze Entwicklertools, um die folgende Seite zu analysieren: https://www.hs-rm.de/lehrlernzentrum/fuer-studierende/studierende-angebote-von-a-bis-z
#
# Wie könnte es gelingen, genau die Links zu identifizieren, die auf Seminare verweisen?

# %% [raw]
# # Platz für Ideen

# %% [markdown]
# ## 3. Webseiten verarbeiten

# %% [markdown]
# Nachdem wir eine Webseite mit `requests` heruntergeladen haben, werden wir die Bibliothek [Beautiful Soup](https://beautiful-soup-4.readthedocs.io/en/latest/) bzw. `bs4` verwenden, um das HTML-Dokument zu **parsen**, d.h. anhand der Struktur die für uns relevanten Informationen zu extrahieren.
#
# Der erste Schritt ist das Importieren der Bibliotheken (die leicht unterschiedliche Syntax hängt mit der objektorientierten Natur von Beautiful Soup zusammen):

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ### Einlesen

# %% [markdown]
# Wie zuvor laden wir die Webseite mit `requests` herunter und speichern sie als String ab.

# %%
page = requests.get('https://www.hs-rm.de/lehrlernzentrum/fuer-studierende/studierende-angebote-von-a-bis-z')

# %% [markdown]
# Mit dem `BeautifulSoup()`-Befehl können wir den HTML-String einlesen. Wir erhalten ein **Objekt**, das viele nützliche Methoden besitzt, um die Seite übersichtlicher darzustellen und bestimmte Elemente zu finden.

# %%
soup = BeautifulSoup(page.content, 'html.parser')

# %% [markdown]
# Die `prettify()`-Methode stellt die Seite ähnlich wie die Entwicklertools dar.

# %%
print(soup.prettify())

# %% [markdown]
# ### Durchsuchen

# %% [markdown]
# *Beautiful Soup* stellt uns zwei intuitive, mächtige Suchfunktionen zur Verfügung:
# - `find` liefert das erste HTML-Element mit bestimmten Kriterien
# - `find_all` liefert alle HTML-Elemente mit bestimmten Kriterien
#
#
# Die **Suchkriterien** werden über die **Funktionsparameter** bestimmt (wir beschränken uns auf die drei grundlegenden, [es gibt aber noch mehr](https://beautiful-soup-4.readthedocs.io/en/latest/#kinds-of-filters):
# ```python
# soup.find('TAG', ATTRIBUT='WERT', string='TEXT')
# ```
# Wir gehen sie Schritt für Schritt an Beispielen durch.

# %%
# Finde den ersten <a>-Tag
soup.find('a')

# %%
# Finde das erste Element mit der id 'c54658'
soup.find(id='c54658')

# %%
# Finde den ersten <h2>-Tag, in dem der String "LLZ" vorkommt
import re
soup.find('h2', string=re.compile('LLZ'))

# %% [markdown]
# ### 🛠️Übung: Elemente finden
# Nutze die `soup.find_all()`-Methode, um alle `<a>`-Elemente auszugeben, in denen der String "Seminar" enthalten ist.

# %%
# Platz für die Aufgabe

# %% [markdown]
# ### Auf Inhalt und Attribute zugreifen

# %% [markdown]
# Nachdem wir die Elemente gefunden haben, die uns interessieren, können wir auf ihren **Inhalt** - also den Text, der auf der Webseite zu sehen ist - zugreifen.

# %%
# Sichtbarer Text der ersten h1-Überschrift
soup.find('h1').text
# Out:
# '\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\tLehrLernZentrum (LLZ)\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t'

# %% [markdown]
# Wie im Beispiel zu sehen ist, kann Webseiten-Text manchmal seltsam formatiert sein. Mit der String-Methode `strip()` lassen sich unnötige Leerzeichen, Tabs und Zeilenumbrüche leicht entfernen.

# %%
# Sichtbarer Text der ersten h1-Überschrift, ohne Leerzeichen
soup.find('h1').text.strip()
# Out:
# 'LehrLernZentrum (LLZ)'

# %% [markdown]
# Oft interessieren uns aber gar nicht die Texte, sondern bestimmte **Attribute** der Elemente. Auf diese können wir wie in einem Dictionary zugreifen.

# %%
# Wert des 'width' Attributs des ersten Bilds
soup.find('img')['width']
# Out:
# '1920'

# %% [markdown]
# ### 🛠️Übung: URLs scrapen
# Nutze die `soup.find_all()`-Methode, um alle `<a>`-Elemente zu finden und gehe sie mit einer `for`-Schleife durch. Falls in ihnen der String "Seminar" enthalten ist, gebe die URL in folgendem Format aus:
# ```
# - [NAME DES SEMINARS]: [URL]
# ```

# %%
# Platz für die Übung

# %% [markdown]
# ## 4. Webseiten *crawlen*

# %% [markdown]
# Wir haben jetzt alle notwendigen Tools, um einen **Crawler** zu entwickeln, der iterativ Seiten abruft und verarbeitet.

# %% [markdown]
# ## 5. Scraping-Ethik

# %% [markdown]
# Webscraping ist zwar nützlich, aber **ethisch teils fragwürdig**. Webseiten, die hochwertige Daten bereitstellen, sind für ihre Existenz oft auf auf menschliche Besuche oder kostenpflichtige APIs angewiesen und **verbieten entsprechend das Scraping** ihrer Inhalte. Wiederum andere Webseiten erlauben es grundsätzlich, bitten aber um eine kurze Wartezeit zwischen Anfragen, um die Server nicht zu überlasten.

# %% [markdown]
# ### Regeln in `robots.txt` beachten
# Welche Regeln für eine Webseite gelten, steht meist in der `robots.txt`-Datei, die auf der obersten Ebene der Webseite zu finden ist. Hier ist z.B. der Inhalt von https://www.hs-rm.de/robots.txt:
# ```
# Sitemap: https:///www.hs-rm.de/sitemap.xml
# User-agent: *
# Allow: /
# Disallow: /typo3/
# ```
# Diese Anweisung ist sehr liberal: Sie erlaubt jegliche Nutzung, mit der Ausnahme von Seiten unter dem 'typo3'-Verzeichnis.

# %% [markdown]
# ### 🧪Experiment: robots.txt
# Schaue dir die `robots.txt`-Datei von www.zeit.de an. Füge dafür '/robots.txt' ans Ende der URL an und öffne die Seite in einem Browser. Wie interpretierst du die Inhalte der Datei?

# %% [raw]
# # Platz für Notizen

# %% [markdown]
# ### Wartezeiten implementieren

# %% [markdown]
# Ein bekannter Cyberangriff ist der sog. [DoS-Angriff](https://de.wikipedia.org/wiki/Denial_of_Service), der in einfachster Form einen Server überlastet, indem in sehr kurzer Zeit sehr viele Anfragen gesendet werden. **Verwantwortungsloses Webscraping kann einen ähnlichen Effekt haben** - so berichtete etwa Wikipedia Anfang 2025 davon, dass [65% der ressourcenintensivsten Anfragen von Crawlern](https://diff.wikimedia.org/2025/04/01/how-crawlers-impact-the-operations-of-the-wikimedia-projects/) stammen.
#
# Eine einfache Möglichkeit, um Serverüberlastung zu vermeiden, ist das Einbauen von Wartezeiten zwischen Anfragen mit Pythons `time.sleep`-Funktion:

# %%
import time

print("Starte Wartezeit...")
time.sleep(5)
print("Wartezeit beendet")
# Out:
# Starte Wartezeit...
# Wartezeit beendet

# %% [markdown]
# ### 🛠️Übung: Zwischen requests warten
# Rufe mit einer `for`-Schleife fünf mal die Seite www.example.com auf, aber warte zwischendurch jeweils eine Sekunde.

# %%
# Platz für die Aufgabe

# %% [markdown]
# ### Sparsam scrapen
# Zu guter Letzt sind hier noch ein paar allgemeine Hinweise zum Webscraping:
# - Rufe Webseiten nur einmal mit `requests.get()` auf und speichere das Ergebnis in einer Variable, statt die Seite mehrmals anzufragen.
# - Vermeide Webscraping gänzlich, wenn APIs als Alternative zur Verfügung stehen.
# - Falls eine Webseite den Aufruf mit `requests.get()` blockiert (z.B. wenn ein 403-Fehler zurückkommt), ist das ein recht sicherer Hinweis darauf, dass die Seite das Scraping verbietet.
# - Lese im Zweifelsfall die Nutzungsbedingungen der Webseite, um zu erfahren, ob und unter welchen Bedingungen Scraping erlaubt ist.
# - Selbst wenn Scraping erlaubt ist, sind die Inhalte der meisten Webseiten urheber- und datenschutzrechtlich geschützt und dürfen nicht ohne Erlaubnis in anderen Kontexten veröffentlicht werden. Das gilt insbesondere für Inhalte hinter Logins und personenbezogene Daten.
