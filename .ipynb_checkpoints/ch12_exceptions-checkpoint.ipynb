# %% [markdown]
# # Teil 12: Ausnahmen
# In vielen Programmen sind **Laufzeitfehler** unvermeidbar: User geben falsche Inputs ein, Dateien wurden verschoben, ein Server reagiert nicht. Um mit diesen Risikofaktoren umzugehen, können in Python vorhersehbare **Ausnahmefälle** definiert und behandelt werden.

# %% [markdown]
# ## 12.1 Ausnahmen abfangen

# %% [markdown]
# Die grundlegende Syntax für **Fehlerbehandlung** besteht aus **zwei Blöcken**:
# ```python
# try:
#     ...
# except:
#     ...
# ```
# In einem ersten `try`-Block wird der Code ausgeführt, der potentiell einen Fehler auslöst (wir sprechen auch vom "Werfen" eines Fehlers). Er wird ggf. nur bis zu der Zeile ausgeführt, in der ein Fehler auftritt.
#
# Danach wird in einem `except`-Block definiert, was das Programm tun soll, falls es tatsächlich zu einem Fehler kommt (wir sprechen auch vom "Fangen" eines Fehlers).

# %%
# Beispiel: Division durch 0 fangen
# Untere Zeile kann auskommentiert werden, um Beispiel ohne Fehlerbehandlung auszuprobieren
# interesting_number = 1 / 0

try:
    interesting_number = 1 / 0
    print("Wow, wir haben erfolgreich durch Null geteilt!")
except:
    print("Wir tun mal so, als ob wir nicht durch Null geteilt hätten...")

print("...dann kann das Programm ganz normal weiterlaufen.")

# %% [markdown]
# ### 🛠️Übung: Input-Validierung (Teil 1)
# Bisher hatten wir keine einfache Möglichkeit, um zu prüfen, ob ein User-Input in eine Zahl umgewandelt werden kann. Mit `try`-`except`-Blöcken geht das.
#
# Ändere den untenstehenden Code so, dass die Typkonvertierung und der `break`-Befehl in einem `try`-Block ausgeführt werden. Fange den potentiellen Fehler in einem `except`-Block auf, der eine aussagekräftige Nachricht ausgibt und zur erneuten Eingabe auffordert.

# %%
while True:
    user_input = input("Gebe eine Ganzzahl ein: ")
    
    # Ab hier anpassen
    user_number = int(user_input)
    break

print("Deine Zahl + 100:", 100 + user_number)

# %% [markdown]
# ### 🤔 Diskussion: Allumfassende Fehlerbehandlung
# Mit dem `try`-`except`-Konstrukt ist es theoretisch möglich, einfach alle möglichen Fehler in einem Programm aufzufangen. Überlege, warum das als schlechter Programmierstil gilt.

# %%
# Warum ist das hier eine schlechte Idee?

try:
    print("Hier beginnt mein langes Programm...")
    # ...
    # ...
    # ...
except:
    pass

print("Programm erfolgreich beendet!")

# %% [markdown]
# ## 12.2 Bestimmte Fehlertypen auffangen

# %% [markdown]
# Es ist gute Programmierpraxis, nur die Fehler aufzufangen, deren Eintreten man erwarten und entsprechend behandeln kann. Dafür lässt sich im `except`-Block der **Fehlertyp** definieren, der aufgefangen werden soll:

# %%
# Beispiel: Fehlerbehandlung, die nur Division durch Null auffängt
try:
    user_number = int(input("Gebe eine Zahl ein, durch die geteilt werden soll: "))
    result = 1 / user_number
    print("Ergebnis:", result)
except ZeroDivisionError:
    print("Das wird nicht klappen.")

print("Programm erfolgreich beendet.")

# %% [markdown]
# ### 🧪Experiment: Fehlertypen identifizieren
# Finde möglichst viele Fehlertypen! Versuche typische Fehler aus den vorherigen Sitzungen und den Hausaufgaben zu reproduzieren und schreibe auf, welcher Name in der Fehlermeldung ausgegeben wird.

# %%
# Hier ist Platz für Fehler

# %% [markdown]
# ### 🛠️Übung: Input-Validierung (Teil 2)
#
# Ändere deinen Code aus der vorhergehenden Übung zur Input-Validierung so, dass nur der relevante Fehlertyp aufgefangen wird!

# %%
# Kopiere hier deinen Code aus "Übung: Input-Validierung (Teil 1)" und entwickle ihn weiter

# %% [markdown]
# ## 12.3 Fehlerbehandlung bei Dateioperationen

# %% [markdown]
# Neben Input-Validierung sind Dateioperationen ein weiterer wichtiger Anwendungsfall für Ausnahmen.

# %% [markdown]
# ### 🛠️Übung: Dateizugriff sicherstellen
#
# Passe den untenstehenden Code an! Der User sollte so lange aufgefordert werden, einen Dateinamen einzugeben, bis er eine tatsächlich existierende Datei angibt.

# %%
# Ändere den Code so, dass ggf. wiederholt nach einem Dateinamen gefragt wird

filename = input("Welche Datei soll geöffnet werden? ")

with open(filename) as f:
    print(f.read())
